# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Read the city data file and store it in a pandas DataFrame.
city_data_df = pd.read_csv("weather_data/clean_cities.csv")
city_data_df.head(10)
# Out:
#    City_ID         City Country                 Date      Lat       Lng  \
# 0        0   Georgetown      MY  2022-10-18 02:18:28   5.4112  100.3354
# 1        1      Aklavik      CA  2022-10-18 02:22:42  68.2191 -135.0107
# 2        2     Yar-Sale      RU  2022-10-18 02:22:43  66.8333   70.8333
# 3        3       Teknaf      BD  2022-10-18 02:22:43  20.8624   92.3058
# 4        4      Fortuna      US  2022-10-18 02:22:44  40.5982 -124.1573
# 5        5        Pevek      RU  2022-10-18 02:22:44  69.7008  170.3133
# 6        6         Jadu      LY  2022-10-18 02:22:45  31.9530   12.0261
# 7        7   San Rafael      AR  2022-10-18 02:22:45 -34.6177  -68.3301
# 8        8  Clyde River      CA  2022-10-18 02:22:46  70.4692  -68.5914
# 9        9    Jamestown      US  2022-10-18 02:22:46  42.0970  -79.2353
#
#    Max Temp  Humidity  Cloudiness  Wind Speed
# 0     84.13        78          20        0.00
# 1     26.51        91         100        4.47
# 2     34.32        93          71       13.76
# 3     79.12        86          98        3.94
# 4     61.93        82           0        8.05
# 5      4.77        93          70        5.06
# 6     58.66        74           0        5.68
# 7     53.56        85         100       14.03
# 8     23.23        86         100        6.91
# 9     40.59        68          75       18.41

# %%
city_data_df.count()
# Out:
# City_ID       567
# City          567
# Country       565
# Date          567
# Lat           567
# Lng           567
# Max Temp      567
# Humidity      567
# Cloudiness    567
# Wind Speed    567
# dtype: int64

# %%
# Extract relevant fields from the DataFrame for plotting. 
lats = city_data_df["Lat"]
max_temps = city_data_df["Max Temp"]
humidity = city_data_df["Humidity"]
cloudiness = city_data_df["Cloudiness"]
wind_speed = city_data_df["Wind Speed"]

# %%
import time

# %%
today = time.time()
today
# Out:
# 1666063541.249571

# %%
today = time.strftime("%x")
today
# Out:
# '10/17/22'

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(lats, 
            max_temps,
            edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title(f"City Latitude vs. Max Temperature "+ time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("weather_data/Fig1.png")

# Show plot
plt.show()

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(lats, 
            humidity,
            edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title(f"City Latitude vs. Humidity "+ time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("weather_data/Fig2.png")

# Show plot
plt.show()

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(lats, 
            cloudiness,
            edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title(f"City Latitude vs. Cloudiness (%) "+ time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("weather_data/Fig2.png")

# Show plot
plt.show()

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(lats, 
            wind_speed,
            edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title(f"City Latitude vs. Wind Speed "+ time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("weather_data/Fig2.png")

# Show plot
plt.show()
