# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# %%
# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 739

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Make an API request for each city 
    try:
       
        # Parse the JSON data
        city_weather = requests.get(city_url).json()
        
        # Parse the JSON and retrieve data.
        city_city = city.title()
        city_country = city_weather['sys']['country']
        city_date = datetime.utcfromtimestamp(city_weather['dt']).strftime('%Y-%m-%d %H:%M:%S')
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_hum = city_weather['main']['humidity']
        city_cloud = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_desc = city_weather['weather'][0]['description']
        
        # Fill City Data list 
        city_data.append({"City": city_city,
                         "Country": city_country,
                         "Date": city_date,
                         "Lat": city_lat,
                         "Lng": city_lng,
                         "Max Temp": city_max_temp,
                         "Humidity": city_hum,
                         "Cloudiness": city_cloud,
                         "Wind Speed": city_wind,
                         "Current Description": city_desc,
                         })
        

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | buala
# Processing Record 2 of Set 1 | alyangula
# Processing Record 3 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 4 of Set 1 | kaitong
# Processing Record 5 of Set 1 | luceville
# City not found. Skipping...
# Processing Record 6 of Set 1 | haibowan
# City not found. Skipping...
# Processing Record 7 of Set 1 | castro
# Processing Record 8 of Set 1 | khatanga
# Processing Record 9 of Set 1 | ushuaia
# Processing Record 10 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 11 of Set 1 | yantzaza
# Processing Record 12 of Set 1 | tabiauea
# City not found. Skipping...
# Processing Record 13 of Set 1 | muravlenko
# Processing Record 14 of Set 1 | vilhena
# Processing Record 15 of Set 1 | mataura
# Processing Record 16 of Set 1 | katherine
# Processing Record 17 of Set 1 | lebu
# Processing Record 18 of Set 1 | kavieng
# Processing Record 19 of Set 1 | qeshm
# Processing Record 20 of Set 1 | hilo
# Processing Record 21 of Set 1 | ilulissat
# Processing Record 22 of Set 1 | atuona
# Processing Record 23 of Set 1 | hobart
# Processing Record 24 of Set 1 | beira
# Processing Record 25 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 26 of Set 1 | lagos
# Processing Record 27 of Set 1 | hermanus
# Processing Record 28 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 29 of Set 1 | severo-yeniseyskiy
# Processing Record 30 of Set 1 | tumbes
# Processing Record 31 of Set 1 | busselton
# Processing Record 32 of Set 1 | georgiyevka
# Processing Record 33 of Set 1 | kushiro
# Processing Record 34 of Set 1 | puerto ayora
# Processing Record 35 of Set 1 | mae hong son
# Processing Record 36 of Set 1 | matagami
# Processing Record 37 of Set 1 | new norfolk
# Processing Record 38 of Set 1 | jurmala
# Processing Record 39 of Set 1 | nikolskoye
# Processing Record 40 of Set 1 | rawannawi
# City not found. Skipping...
# Processing Record 41 of Set 1 | yellowknife
# Processing Record 42 of Set 1 | vaini
# Processing Record 43 of Set 1 | yerbogachen
# Processing Record 44 of Set 1 | lata
# Processing Record 45 of Set 1 | pisco
# Processing Record 46 of Set 1 | ribeira grande
# Processing Record 47 of Set 1 | zemio
# Processing Record 48 of Set 1 | herne bay
# Processing Record 49 of Set 1 | rikitea
# Processing Record 50 of Set 1 | kendari
# Processing Record 1 of Set 2 | beringovskiy
# Processing Record 2 of Set 2 | albany
# Processing Record 3 of Set 2 | poronaysk
# Processing Record 4 of Set 2 | te anau
# Processing Record 5 of Set 2 | nizhnevartovsk
# Processing Record 6 of Set 2 | ouallam
# Processing Record 7 of Set 2 | linxia
# Processing Record 8 of Set 2 | tasiilaq
# Processing Record 9 of Set 2 | butaritari
# Processing Record 10 of Set 2 | burnie
# Processing Record 11 of Set 2 | coquimbo
# Processing Record 12 of Set 2 | jabiru
# City not found. Skipping...
# Processing Record 13 of Set 2 | avera
# Processing Record 14 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 15 of Set 2 | jamestown
# Processing Record 16 of Set 2 | greencastle
# Processing Record 17 of Set 2 | qaanaaq
# Processing Record 18 of Set 2 | aasiaat
# Processing Record 19 of Set 2 | cumberland
# Processing Record 20 of Set 2 | porto novo
# Processing Record 21 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 22 of Set 2 | esperance
# Processing Record 23 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 24 of Set 2 | provideniya
# Processing Record 25 of Set 2 | tual
# Processing Record 26 of Set 2 | barraute
# Processing Record 27 of Set 2 | avarua
# Processing Record 28 of Set 2 | bluff
# Processing Record 29 of Set 2 | sawakin
# Processing Record 30 of Set 2 | vardo
# Processing Record 31 of Set 2 | dikson
# Processing Record 32 of Set 2 | karwar
# Processing Record 33 of Set 2 | barrow
# Processing Record 34 of Set 2 | chenzhou
# Processing Record 35 of Set 2 | cape town
# Processing Record 36 of Set 2 | bobonong
# City not found. Skipping...
# Processing Record 37 of Set 2 | launceston
# Processing Record 38 of Set 2 | cherskiy
# Processing Record 39 of Set 2 | arlit
# Processing Record 40 of Set 2 | antipino
# Processing Record 41 of Set 2 | novorzhev
# Processing Record 42 of Set 2 | palmer
# Processing Record 43 of Set 2 | tuktoyaktuk
# Processing Record 44 of Set 2 | sistranda
# Processing Record 45 of Set 2 | katsuura
# Processing Record 46 of Set 2 | bartica
# Processing Record 47 of Set 2 | labuhan
# Processing Record 48 of Set 2 | veraval
# Processing Record 49 of Set 2 | ancud
# Processing Record 50 of Set 2 | hithadhoo
# Processing Record 1 of Set 3 | kaitangata
# Processing Record 2 of Set 3 | saint george
# Processing Record 3 of Set 3 | lompoc
# Processing Record 4 of Set 3 | carolina
# Processing Record 5 of Set 3 | kodiak
# Processing Record 6 of Set 3 | isangel
# Processing Record 7 of Set 3 | el jicaro
# Processing Record 8 of Set 3 | ponta do sol
# Processing Record 9 of Set 3 | pelym
# Processing Record 10 of Set 3 | thompson
# Processing Record 11 of Set 3 | abu kamal
# Processing Record 12 of Set 3 | tavda
# Processing Record 13 of Set 3 | saskylakh
# Processing Record 14 of Set 3 | klaksvik
# Processing Record 15 of Set 3 | miri
# Processing Record 16 of Set 3 | leningradskiy
# Processing Record 17 of Set 3 | punta arenas
# Processing Record 18 of Set 3 | siwana
# Processing Record 19 of Set 3 | san quintin
# Processing Record 20 of Set 3 | makakilo city
# Processing Record 21 of Set 3 | carmarthen
# Processing Record 22 of Set 3 | port alfred
# Processing Record 23 of Set 3 | souillac
# Processing Record 24 of Set 3 | marzuq
# Processing Record 25 of Set 3 | pingliang
# Processing Record 26 of Set 3 | manga
# Processing Record 27 of Set 3 | sarangani
# Processing Record 28 of Set 3 | kruisfontein
# Processing Record 29 of Set 3 | sabya
# Processing Record 30 of Set 3 | petropavlovsk-kamchatskiy
# Processing Record 31 of Set 3 | kavaratti
# Processing Record 32 of Set 3 | kupang
# Processing Record 33 of Set 3 | byron bay
# Processing Record 34 of Set 3 | rawson
# Processing Record 35 of Set 3 | adiake
# Processing Record 36 of Set 3 | kapaa
# Processing Record 37 of Set 3 | tikapur
# Processing Record 38 of Set 3 | san patricio
# Processing Record 39 of Set 3 | east london
# Processing Record 40 of Set 3 | norman wells
# Processing Record 41 of Set 3 | mareeba
# Processing Record 42 of Set 3 | kuche
# City not found. Skipping...
# Processing Record 43 of Set 3 | vanderhoof
# Processing Record 44 of Set 3 | spearfish
# Processing Record 45 of Set 3 | chokurdakh
# Processing Record 46 of Set 3 | hasaki
# Processing Record 47 of Set 3 | anadyr
# Processing Record 48 of Set 3 | galiwinku
# City not found. Skipping...
# Processing Record 49 of Set 3 | phan thiet
# Processing Record 50 of Set 3 | saint-philippe
# Processing Record 1 of Set 4 | filotion
# Processing Record 2 of Set 4 | taolanaro
# City not found. Skipping...
# Processing Record 3 of Set 4 | waipawa
# Processing Record 4 of Set 4 | mattru
# Processing Record 5 of Set 4 | barcelos
# Processing Record 6 of Set 4 | olafsvik
# Processing Record 7 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 8 of Set 4 | satitoa
# City not found. Skipping...
# Processing Record 9 of Set 4 | damghan
# Processing Record 10 of Set 4 | dharan
# Processing Record 11 of Set 4 | virginia beach
# Processing Record 12 of Set 4 | upernavik
# Processing Record 13 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 14 of Set 4 | seoul
# Processing Record 15 of Set 4 | goya
# Processing Record 16 of Set 4 | bethel
# Processing Record 17 of Set 4 | gamba
# Processing Record 18 of Set 4 | blagoyevo
# Processing Record 19 of Set 4 | carnarvon
# Processing Record 20 of Set 4 | chuy
# Processing Record 21 of Set 4 | longyearbyen
# Processing Record 22 of Set 4 | constitucion
# Processing Record 23 of Set 4 | khoy
# Processing Record 24 of Set 4 | opuwo
# Processing Record 25 of Set 4 | naestved
# Processing Record 26 of Set 4 | novovarshavka
# Processing Record 27 of Set 4 | mar del plata
# Processing Record 28 of Set 4 | bolobo
# Processing Record 29 of Set 4 | murdochville
# Processing Record 30 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 31 of Set 4 | kaffrine
# Processing Record 32 of Set 4 | port lincoln
# Processing Record 33 of Set 4 | ahipara
# Processing Record 34 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 35 of Set 4 | mitsamiouli
# Processing Record 36 of Set 4 | tabas
# Processing Record 37 of Set 4 | port hardy
# Processing Record 38 of Set 4 | ondangwa
# Processing Record 39 of Set 4 | guerrero negro
# Processing Record 40 of Set 4 | duluth
# Processing Record 41 of Set 4 | xinqing
# Processing Record 42 of Set 4 | novyy urengoy
# Processing Record 43 of Set 4 | sakakah
# Processing Record 44 of Set 4 | vangaindrano
# Processing Record 45 of Set 4 | izumo
# Processing Record 46 of Set 4 | lang son
# Processing Record 47 of Set 4 | takaka
# Processing Record 48 of Set 4 | prince rupert
# Processing Record 49 of Set 4 | sioux lookout
# Processing Record 50 of Set 4 | tawkar
# City not found. Skipping...
# Processing Record 1 of Set 5 | malwan
# City not found. Skipping...
# Processing Record 2 of Set 5 | kahului
# Processing Record 3 of Set 5 | arraial do cabo
# Processing Record 4 of Set 5 | tiksi
# Processing Record 5 of Set 5 | college
# Processing Record 6 of Set 5 | chipata
# Processing Record 7 of Set 5 | karasuk
# Processing Record 8 of Set 5 | pakwach
# City not found. Skipping...
# Processing Record 9 of Set 5 | uyutne
# Processing Record 10 of Set 5 | ostrovnoy
# Processing Record 11 of Set 5 | sorland
# Processing Record 12 of Set 5 | belaya gora
# Processing Record 13 of Set 5 | mahebourg
# Processing Record 14 of Set 5 | dudinka
# Processing Record 15 of Set 5 | silver city
# Processing Record 16 of Set 5 | adrar
# Processing Record 17 of Set 5 | qunduz
# Processing Record 18 of Set 5 | buraydah
# Processing Record 19 of Set 5 | henties bay
# Processing Record 20 of Set 5 | dingle
# Processing Record 21 of Set 5 | broken hill
# Processing Record 22 of Set 5 | fortuna
# Processing Record 23 of Set 5 | ilhabela
# Processing Record 24 of Set 5 | port shepstone
# Processing Record 25 of Set 5 | berlevag
# Processing Record 26 of Set 5 | taucha
# Processing Record 27 of Set 5 | seoni malwa
# Processing Record 28 of Set 5 | sept-iles
# Processing Record 29 of Set 5 | urgut
# Processing Record 30 of Set 5 | magole
# Processing Record 31 of Set 5 | cidreira
# Processing Record 32 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 33 of Set 5 | bredasdorp
# Processing Record 34 of Set 5 | meulaboh
# Processing Record 35 of Set 5 | japura
# Processing Record 36 of Set 5 | victoria
# Processing Record 37 of Set 5 | cordoba
# Processing Record 38 of Set 5 | caravelas
# Processing Record 39 of Set 5 | port elizabeth
# Processing Record 40 of Set 5 | colombo
# Processing Record 41 of Set 5 | bonthe
# Processing Record 42 of Set 5 | talnakh
# Processing Record 43 of Set 5 | bratsk
# Processing Record 44 of Set 5 | beniganj
# Processing Record 45 of Set 5 | mount isa
# Processing Record 46 of Set 5 | bengkulu
# Processing Record 47 of Set 5 | flin flon
# Processing Record 48 of Set 5 | bocos
# Processing Record 49 of Set 5 | santa cruz
# Processing Record 50 of Set 5 | hami
# Processing Record 1 of Set 6 | hualmay
# Processing Record 2 of Set 6 | chapais
# Processing Record 3 of Set 6 | georgetown
# Processing Record 4 of Set 6 | havoysund
# Processing Record 5 of Set 6 | gornopravdinsk
# Processing Record 6 of Set 6 | stornoway
# Processing Record 7 of Set 6 | ndago
# Processing Record 8 of Set 6 | terra santa
# Processing Record 9 of Set 6 | datong
# Processing Record 10 of Set 6 | maceio
# Processing Record 11 of Set 6 | outlook
# Processing Record 12 of Set 6 | nalut
# Processing Record 13 of Set 6 | tasbuget
# City not found. Skipping...
# Processing Record 14 of Set 6 | yumen
# Processing Record 15 of Set 6 | camalu
# Processing Record 16 of Set 6 | haines junction
# Processing Record 17 of Set 6 | diego de almagro
# Processing Record 18 of Set 6 | matara
# Processing Record 19 of Set 6 | narsaq
# Processing Record 20 of Set 6 | cierna nad tisou
# Processing Record 21 of Set 6 | santa isabel do rio negro
# Processing Record 22 of Set 6 | torbay
# Processing Record 23 of Set 6 | yulara
# Processing Record 24 of Set 6 | huilong
# Processing Record 25 of Set 6 | cabo san lucas
# Processing Record 26 of Set 6 | zhangjiakou
# Processing Record 27 of Set 6 | lima
# Processing Record 28 of Set 6 | cap malheureux
# Processing Record 29 of Set 6 | road town
# Processing Record 30 of Set 6 | nishihara
# Processing Record 31 of Set 6 | huarmey
# Processing Record 32 of Set 6 | kailua
# Processing Record 33 of Set 6 | talara
# Processing Record 34 of Set 6 | atikokan
# Processing Record 35 of Set 6 | poum
# Processing Record 36 of Set 6 | kamenskoye
# City not found. Skipping...
# Processing Record 37 of Set 6 | gushikawa
# Processing Record 38 of Set 6 | nanortalik
# Processing Record 39 of Set 6 | sitka
# Processing Record 40 of Set 6 | oranjemund
# Processing Record 41 of Set 6 | takoradi
# Processing Record 42 of Set 6 | along
# Processing Record 43 of Set 6 | half moon bay
# Processing Record 44 of Set 6 | benalla
# Processing Record 45 of Set 6 | moranbah
# Processing Record 46 of Set 6 | rajec
# Processing Record 47 of Set 6 | feicheng
# Processing Record 48 of Set 6 | ballina
# Processing Record 49 of Set 6 | ola
# Processing Record 50 of Set 6 | unai
# Processing Record 1 of Set 7 | brownwood
# Processing Record 2 of Set 7 | albac
# Processing Record 3 of Set 7 | nome
# Processing Record 4 of Set 7 | sabha
# Processing Record 5 of Set 7 | mittagong
# Processing Record 6 of Set 7 | husavik
# Processing Record 7 of Set 7 | airai
# Processing Record 8 of Set 7 | tura
# Processing Record 9 of Set 7 | sibu
# Processing Record 10 of Set 7 | vestmannaeyjar
# Processing Record 11 of Set 7 | dalnerechensk
# Processing Record 12 of Set 7 | zhigansk
# Processing Record 13 of Set 7 | tortoli
# Processing Record 14 of Set 7 | hanyang
# Processing Record 15 of Set 7 | mahbubabad
# Processing Record 16 of Set 7 | faanui
# Processing Record 17 of Set 7 | sassandra
# Processing Record 18 of Set 7 | sarakhs
# Processing Record 19 of Set 7 | samarai
# Processing Record 20 of Set 7 | azul
# Processing Record 21 of Set 7 | acapulco
# Processing Record 22 of Set 7 | turukhansk
# Processing Record 23 of Set 7 | saint-augustin
# Processing Record 24 of Set 7 | westport
# Processing Record 25 of Set 7 | mnogovershinnyy
# Processing Record 26 of Set 7 | sapu
# Processing Record 27 of Set 7 | sisimiut
# Processing Record 28 of Set 7 | uruacu
# Processing Record 29 of Set 7 | iberia
# Processing Record 30 of Set 7 | alpena
# Processing Record 31 of Set 7 | zhaotong
# Processing Record 32 of Set 7 | pangody
# Processing Record 33 of Set 7 | alofi
# Processing Record 34 of Set 7 | antofagasta
# Processing Record 35 of Set 7 | roswell
# Processing Record 36 of Set 7 | zhangye
# Processing Record 37 of Set 7 | troitskoye
# Processing Record 38 of Set 7 | san policarpo
# Processing Record 39 of Set 7 | san felix
# Processing Record 40 of Set 7 | ubata
# Processing Record 41 of Set 7 | aanekoski
# Processing Record 42 of Set 7 | dorado
# Processing Record 43 of Set 7 | salalah
# Processing Record 44 of Set 7 | san ramon
# Processing Record 45 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 46 of Set 7 | qatana
# Processing Record 47 of Set 7 | mahaicony
# City not found. Skipping...
# Processing Record 48 of Set 7 | vila velha
# Processing Record 49 of Set 7 | la ronge
# Processing Record 50 of Set 7 | stromness
# Processing Record 1 of Set 8 | kanye
# Processing Record 2 of Set 8 | karratha
# Processing Record 3 of Set 8 | margate
# Processing Record 4 of Set 8 | raudeberg
# Processing Record 5 of Set 8 | urfa
# City not found. Skipping...
# Processing Record 6 of Set 8 | visby
# Processing Record 7 of Set 8 | tulun
# Processing Record 8 of Set 8 | yermekeyevo
# Processing Record 9 of Set 8 | toora-khem
# Processing Record 10 of Set 8 | nemuro
# Processing Record 11 of Set 8 | kenai
# Processing Record 12 of Set 8 | matehuala
# Processing Record 13 of Set 8 | bad ems
# Processing Record 14 of Set 8 | asau
# Processing Record 15 of Set 8 | hambantota
# Processing Record 16 of Set 8 | louisbourg
# City not found. Skipping...
# Processing Record 17 of Set 8 | karachi
# Processing Record 18 of Set 8 | methoni
# Processing Record 19 of Set 8 | bara
# Processing Record 20 of Set 8 | rakhya
# City not found. Skipping...
# Processing Record 21 of Set 8 | sain alto
# Processing Record 22 of Set 8 | akdepe
# Processing Record 23 of Set 8 | omboue
# Processing Record 24 of Set 8 | port-gentil
# Processing Record 25 of Set 8 | shitanjing
# Processing Record 26 of Set 8 | porto belo
# Processing Record 27 of Set 8 | oranjestad
# Processing Record 28 of Set 8 | luderitz
# Processing Record 29 of Set 8 | weligama
# Processing Record 30 of Set 8 | gubkinskiy
# Processing Record 31 of Set 8 | kashi
# Processing Record 32 of Set 8 | laguna de perlas
# Processing Record 33 of Set 8 | tetouan
# Processing Record 34 of Set 8 | luanda
# Processing Record 35 of Set 8 | shimanovsk
# Processing Record 36 of Set 8 | iglesias
# Processing Record 37 of Set 8 | iquitos
# Processing Record 38 of Set 8 | vilyuysk
# Processing Record 39 of Set 8 | middelharnis
# Processing Record 40 of Set 8 | jinka
# Processing Record 41 of Set 8 | gat
# Processing Record 42 of Set 8 | angoche
# Processing Record 43 of Set 8 | carmen del parana
# Processing Record 44 of Set 8 | geraldton
# Processing Record 45 of Set 8 | lagoa
# Processing Record 46 of Set 8 | upata
# Processing Record 47 of Set 8 | jalu
# Processing Record 48 of Set 8 | bosanska gradiska
# Processing Record 49 of Set 8 | kalmunai
# Processing Record 50 of Set 8 | pousat
# City not found. Skipping...
# Processing Record 1 of Set 9 | quelimane
# Processing Record 2 of Set 9 | baglung
# Processing Record 3 of Set 9 | flinders
# Processing Record 4 of Set 9 | rafai
# Processing Record 5 of Set 9 | sechura
# Processing Record 6 of Set 9 | itarema
# Processing Record 7 of Set 9 | minab
# Processing Record 8 of Set 9 | dali
# Processing Record 9 of Set 9 | hobyo
# Processing Record 10 of Set 9 | aklavik
# Processing Record 11 of Set 9 | kandrian
# Processing Record 12 of Set 9 | east moline
# Processing Record 13 of Set 9 | cardonal
# Processing Record 14 of Set 9 | xinxiang
# Processing Record 15 of Set 9 | jardim
# Processing Record 16 of Set 9 | pachino
# Processing Record 17 of Set 9 | dabou
# Processing Record 18 of Set 9 | ventersburg
# Processing Record 19 of Set 9 | viligili
# City not found. Skipping...
# Processing Record 20 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 21 of Set 9 | saldanha
# Processing Record 22 of Set 9 | koungou
# Processing Record 23 of Set 9 | cockburn harbour
# City not found. Skipping...
# Processing Record 24 of Set 9 | padang
# Processing Record 25 of Set 9 | egvekinot
# Processing Record 26 of Set 9 | san andres
# Processing Record 27 of Set 9 | artyom
# Processing Record 28 of Set 9 | ghazipur
# Processing Record 29 of Set 9 | bandarbeyla
# Processing Record 30 of Set 9 | changji
# Processing Record 31 of Set 9 | wamba
# Processing Record 32 of Set 9 | bolungarvik
# City not found. Skipping...
# Processing Record 33 of Set 9 | lamu
# Processing Record 34 of Set 9 | inta
# Processing Record 35 of Set 9 | pangai
# Processing Record 36 of Set 9 | arona
# Processing Record 37 of Set 9 | falkoping
# City not found. Skipping...
# Processing Record 38 of Set 9 | barguzin
# Processing Record 39 of Set 9 | kopervik
# Processing Record 40 of Set 9 | pedernales
# Processing Record 41 of Set 9 | wulanhaote
# City not found. Skipping...
# Processing Record 42 of Set 9 | alta floresta
# Processing Record 43 of Set 9 | izhma
# Processing Record 44 of Set 9 | rocha
# Processing Record 45 of Set 9 | vostok
# Processing Record 46 of Set 9 | talcahuano
# Processing Record 47 of Set 9 | soe
# Processing Record 48 of Set 9 | ngukurr
# City not found. Skipping...
# Processing Record 49 of Set 9 | port hedland
# Processing Record 50 of Set 9 | arman
# Processing Record 1 of Set 10 | ust-ilimsk
# Processing Record 2 of Set 10 | tingo maria
# Processing Record 3 of Set 10 | guasdualito
# Processing Record 4 of Set 10 | grindavik
# Processing Record 5 of Set 10 | dunedin
# Processing Record 6 of Set 10 | hope
# Processing Record 7 of Set 10 | minsk
# Processing Record 8 of Set 10 | naze
# Processing Record 9 of Set 10 | mayo
# Processing Record 10 of Set 10 | petawawa
# Processing Record 11 of Set 10 | riyadh
# Processing Record 12 of Set 10 | morgan city
# Processing Record 13 of Set 10 | vanimo
# Processing Record 14 of Set 10 | tursunzoda
# Processing Record 15 of Set 10 | quatre cocos
# Processing Record 16 of Set 10 | mglin
# Processing Record 17 of Set 10 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 18 of Set 10 | ternate
# Processing Record 19 of Set 10 | kysyl-syr
# Processing Record 20 of Set 10 | makokou
# Processing Record 21 of Set 10 | edwardsville
# Processing Record 22 of Set 10 | awbari
# Processing Record 23 of Set 10 | homer
# Processing Record 24 of Set 10 | altamont
# Processing Record 25 of Set 10 | monrovia
# Processing Record 26 of Set 10 | lorengau
# Processing Record 27 of Set 10 | pacific grove
# Processing Record 28 of Set 10 | kayan
# Processing Record 29 of Set 10 | temiscaming
# Processing Record 30 of Set 10 | bambous virieux
# Processing Record 31 of Set 10 | yelovo
# Processing Record 32 of Set 10 | broome
# Processing Record 33 of Set 10 | valparaiso
# Processing Record 34 of Set 10 | genhe
# Processing Record 35 of Set 10 | umm kaddadah
# Processing Record 36 of Set 10 | attawapiskat
# City not found. Skipping...
# Processing Record 37 of Set 10 | sao filipe
# Processing Record 38 of Set 10 | elizabeth city
# Processing Record 39 of Set 10 | ruatoria
# City not found. Skipping...
# Processing Record 40 of Set 10 | gelibolu
# Processing Record 41 of Set 10 | mulchen
# Processing Record 42 of Set 10 | amderma
# City not found. Skipping...
# Processing Record 43 of Set 10 | maghama
# City not found. Skipping...
# Processing Record 44 of Set 10 | luau
# Processing Record 45 of Set 10 | bastia
# Processing Record 46 of Set 10 | namibe
# Processing Record 47 of Set 10 | guiratinga
# Processing Record 48 of Set 10 | aksarka
# Processing Record 49 of Set 10 | kocevje
# Processing Record 50 of Set 10 | saint-denis
# Processing Record 1 of Set 11 | clyde river
# Processing Record 2 of Set 11 | aligudarz
# Processing Record 3 of Set 11 | namatanai
# Processing Record 4 of Set 11 | jaten
# Processing Record 5 of Set 11 | athabasca
# Processing Record 6 of Set 11 | ati
# Processing Record 7 of Set 11 | lixourion
# Processing Record 8 of Set 11 | tuatapere
# Processing Record 9 of Set 11 | agua blanca
# Processing Record 10 of Set 11 | hay river
# Processing Record 11 of Set 11 | marsa matruh
# Processing Record 12 of Set 11 | bolgar
# Processing Record 13 of Set 11 | hofn
# Processing Record 14 of Set 11 | alice springs
# Processing Record 15 of Set 11 | salinas
# Processing Record 16 of Set 11 | chegdomyn
# Processing Record 17 of Set 11 | kushva
# Processing Record 18 of Set 11 | hun
# Processing Record 19 of Set 11 | loreto
# Processing Record 20 of Set 11 | matay
# Processing Record 21 of Set 11 | joshimath
# Processing Record 22 of Set 11 | nioro
# Processing Record 23 of Set 11 | linxi
# Processing Record 24 of Set 11 | manono
# Processing Record 25 of Set 11 | yumaguzino
# Processing Record 26 of Set 11 | samusu
# City not found. Skipping...
# Processing Record 27 of Set 11 | lolua
# City not found. Skipping...
# Processing Record 28 of Set 11 | wanning
# Processing Record 29 of Set 11 | appingedam
# Processing Record 30 of Set 11 | doha
# Processing Record 31 of Set 11 | anzio
# Processing Record 32 of Set 11 | cuxhaven
# Processing Record 33 of Set 11 | kyra
# Processing Record 34 of Set 11 | culebra
# Processing Record 35 of Set 11 | walvis bay
# Processing Record 36 of Set 11 | ingham
# Processing Record 37 of Set 11 | vila do maio
# Processing Record 38 of Set 11 | nelson bay
# Processing Record 39 of Set 11 | liaqatabad
# Processing Record 40 of Set 11 | borujerd
# Processing Record 41 of Set 11 | kuminskiy
# Processing Record 42 of Set 11 | tabou
# Processing Record 43 of Set 11 | codrington
# Processing Record 44 of Set 11 | vao
# Processing Record 45 of Set 11 | freetown
# Processing Record 46 of Set 11 | awjilah
# Processing Record 47 of Set 11 | aksu
# Processing Record 48 of Set 11 | mweka
# Processing Record 49 of Set 11 | kiunga
# Processing Record 50 of Set 11 | hamilton
# Processing Record 1 of Set 12 | bhadra
# Processing Record 2 of Set 12 | wanaka
# Processing Record 3 of Set 12 | lavrentiya
# Processing Record 4 of Set 12 | kutum
# Processing Record 5 of Set 12 | itaituba
# Processing Record 6 of Set 12 | tete
# Processing Record 7 of Set 12 | sobolevo
# Processing Record 8 of Set 12 | bayanday
# Processing Record 9 of Set 12 | pevek
# Processing Record 10 of Set 12 | baykit
# Processing Record 11 of Set 12 | bozuyuk
# Processing Record 12 of Set 12 | nauchnyy gorodok
# Processing Record 13 of Set 12 | komsomolskiy
# Processing Record 14 of Set 12 | tourlaville
# Processing Record 15 of Set 12 | brawley
# Processing Record 16 of Set 12 | luba
# Processing Record 17 of Set 12 | arkhangelsk
# Processing Record 18 of Set 12 | goma
# Processing Record 19 of Set 12 | muroto
# Processing Record 20 of Set 12 | miranorte
# City not found. Skipping...
# Processing Record 21 of Set 12 | tamale
# Processing Record 22 of Set 12 | san jose
# Processing Record 23 of Set 12 | almaznyy
# Processing Record 24 of Set 12 | mukhen
# Processing Record 25 of Set 12 | belyy yar
# Processing Record 26 of Set 12 | rungata
# City not found. Skipping...
# Processing Record 27 of Set 12 | kochi
# Processing Record 28 of Set 12 | aripuana
# Processing Record 29 of Set 12 | ephrata
# Processing Record 30 of Set 12 | ust-uda
# Processing Record 31 of Set 12 | gagra
# Processing Record 32 of Set 12 | innisfail
# Processing Record 33 of Set 12 | eureka
# Processing Record 34 of Set 12 | sandwick
# Processing Record 35 of Set 12 | luorong
# Processing Record 36 of Set 12 | nouadhibou
# Processing Record 37 of Set 12 | george town
# Processing Record 38 of Set 12 | lakatoro
# Processing Record 39 of Set 12 | daru
# Processing Record 40 of Set 12 | pamanukan
# Processing Record 41 of Set 12 | hubli
# Processing Record 42 of Set 12 | esna
# Processing Record 43 of Set 12 | alegrete
# Processing Record 44 of Set 12 | hegang
# Processing Record 45 of Set 12 | voh
# Processing Record 46 of Set 12 | xuchang
# Processing Record 47 of Set 12 | mae sai
# Processing Record 48 of Set 12 | phek
# Processing Record 49 of Set 12 | tshikapa
# Processing Record 50 of Set 12 | oyugis
# Processing Record 1 of Set 13 | portland
# Processing Record 2 of Set 13 | qaqortoq
# Processing Record 3 of Set 13 | north bend
# Processing Record 4 of Set 13 | galesong
# Processing Record 5 of Set 13 | iqaluit
# Processing Record 6 of Set 13 | ambilobe
# Processing Record 7 of Set 13 | ofunato
# Processing Record 8 of Set 13 | yanam
# Processing Record 9 of Set 13 | chumikan
# Processing Record 10 of Set 13 | bakchar
# Processing Record 11 of Set 13 | rustenburg
# Processing Record 12 of Set 13 | inhambane
# Processing Record 13 of Set 13 | toledo
# Processing Record 14 of Set 13 | ngama
# Processing Record 15 of Set 13 | camabatela
# Processing Record 16 of Set 13 | formosa do rio preto
# Processing Record 17 of Set 13 | senneterre
# Processing Record 18 of Set 13 | greeneville
# Processing Record 19 of Set 13 | san cristobal
# Processing Record 20 of Set 13 | malinovskiy
# Processing Record 21 of Set 13 | barawe
# City not found. Skipping...
# Processing Record 22 of Set 13 | sharanga
# Processing Record 23 of Set 13 | skjervoy
# Processing Record 24 of Set 13 | taltal
# Processing Record 25 of Set 13 | honiara
# Processing Record 26 of Set 13 | cairns
# Processing Record 27 of Set 13 | bereda
# Processing Record 28 of Set 13 | mandurah
# Processing Record 29 of Set 13 | domoni
# Processing Record 30 of Set 13 | sorong
# Processing Record 31 of Set 13 | arinos
# Processing Record 32 of Set 13 | shirokiy
# Processing Record 33 of Set 13 | iwanai
# Processing Record 34 of Set 13 | kudahuvadhoo
# Processing Record 35 of Set 13 | voloshka
# Processing Record 36 of Set 13 | sebeta
# Processing Record 37 of Set 13 | mahibadhoo
# Processing Record 38 of Set 13 | lagdo
# Processing Record 39 of Set 13 | koumac
# Processing Record 40 of Set 13 | shenjiamen
# Processing Record 41 of Set 13 | ondjiva
# Processing Record 42 of Set 13 | rio bueno
# Processing Record 43 of Set 13 | yanliang
# Processing Record 44 of Set 13 | fairmont
# Processing Record 45 of Set 13 | manoel urbano
# Processing Record 46 of Set 13 | kalikino
# Processing Record 47 of Set 13 | teguise
# Processing Record 48 of Set 13 | carnot
# Processing Record 49 of Set 13 | verkhoyansk
# Processing Record 50 of Set 13 | kondinskoye
# Processing Record 1 of Set 14 | ansalta
# Processing Record 2 of Set 14 | easton
# Processing Record 3 of Set 14 | saint paul
# Processing Record 4 of Set 14 | santa maria del oro
# Processing Record 5 of Set 14 | andarab
# City not found. Skipping...
# Processing Record 6 of Set 14 | sri aman
# Processing Record 7 of Set 14 | maturin
# Processing Record 8 of Set 14 | monforte de lemos
# Processing Record 9 of Set 14 | kibala
# Processing Record 10 of Set 14 | evensk
# Processing Record 11 of Set 14 | nam tha
# City not found. Skipping...
# Processing Record 12 of Set 14 | mbandaka
# Processing Record 13 of Set 14 | ippy
# Processing Record 14 of Set 14 | west bay
# Processing Record 15 of Set 14 | lhokseumawe
# Processing Record 16 of Set 14 | bathsheba
# Processing Record 17 of Set 14 | ponta delgada
# Processing Record 18 of Set 14 | xicotencatl
# Processing Record 19 of Set 14 | guangyuan
# Processing Record 20 of Set 14 | sambava
# Processing Record 21 of Set 14 | udachnyy
# Processing Record 22 of Set 14 | galway
# Processing Record 23 of Set 14 | slave lake
# Processing Record 24 of Set 14 | lucea
# Processing Record 25 of Set 14 | carroll
# Processing Record 26 of Set 14 | pimentel
# Processing Record 27 of Set 14 | ranau
# Processing Record 28 of Set 14 | saint anthony
# Processing Record 29 of Set 14 | tuy hoa
# Processing Record 30 of Set 14 | kushalgarh
# Processing Record 31 of Set 14 | tautira
# Processing Record 32 of Set 14 | othonoi
# City not found. Skipping...
# Processing Record 33 of Set 14 | puerto lempira
# Processing Record 34 of Set 14 | vanavara
# Processing Record 35 of Set 14 | fountain
# Processing Record 36 of Set 14 | general roca
# Processing Record 37 of Set 14 | tibacuy
# Processing Record 38 of Set 14 | amga
# Processing Record 39 of Set 14 | luwuk
# Processing Record 40 of Set 14 | cheuskiny
# City not found. Skipping...
# Processing Record 41 of Set 14 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 42 of Set 14 | dordrecht
# Processing Record 43 of Set 14 | beauvechain
# Processing Record 44 of Set 14 | bac lieu
# Processing Record 45 of Set 14 | waingapu
# Processing Record 46 of Set 14 | livny
# Processing Record 47 of Set 14 | sechelt
# Processing Record 48 of Set 14 | tsabong
# Processing Record 49 of Set 14 | mount gambier
# Processing Record 50 of Set 14 | aloleng
# Processing Record 1 of Set 15 | numan
# Processing Record 2 of Set 15 | severo-kurilsk
# Processing Record 3 of Set 15 | rongai
# Processing Record 4 of Set 15 | vila franca do campo
# Processing Record 5 of Set 15 | cuamba
# Processing Record 6 of Set 15 | touros
# Processing Record 7 of Set 15 | fort collins
# Processing Record 8 of Set 15 | bima
# Processing Record 9 of Set 15 | berezovyy
# Processing Record 10 of Set 15 | mataram
# Processing Record 11 of Set 15 | male
# Processing Record 12 of Set 15 | zabol
# Processing Record 13 of Set 15 | chadiza
# Processing Record 14 of Set 15 | marawi
# Processing Record 15 of Set 15 | segou
# Processing Record 16 of Set 15 | kulhudhuffushi
# Processing Record 17 of Set 15 | pahrump
# Processing Record 18 of Set 15 | the valley
# Processing Record 19 of Set 15 | bogorodskoye
# Processing Record 20 of Set 15 | cocobeach
# Processing Record 21 of Set 15 | colares
# Processing Record 22 of Set 15 | christchurch
# Processing Record 23 of Set 15 | sidi ali
# Processing Record 24 of Set 15 | opobo
# City not found. Skipping...
# Processing Record 25 of Set 15 | churapcha
# Processing Record 26 of Set 15 | hihifo
# City not found. Skipping...
# Processing Record 27 of Set 15 | pizarro
# Processing Record 28 of Set 15 | celestun
# Processing Record 29 of Set 15 | qiqihar
# Processing Record 30 of Set 15 | ambon
# Processing Record 31 of Set 15 | maragogi
# Processing Record 32 of Set 15 | kamenka
# Processing Record 33 of Set 15 | ulladulla
# Processing Record 34 of Set 15 | mahon
# Processing Record 35 of Set 15 | coahuayana
# Processing Record 36 of Set 15 | russell
# Processing Record 37 of Set 15 | denau
# City not found. Skipping...
# Processing Record 38 of Set 15 | tessalit
# Processing Record 39 of Set 15 | nitra
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 681

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#          City Country                 Date      Lat       Lng  Max Temp  \
# 0       Buala      SB  2023-01-03 00:00:34  -8.1450  159.5921     84.65
# 1   Alyangula      AU  2023-01-03 00:00:35 -13.8483  136.4192     82.74
# 2     Kaitong      CN  2023-01-03 00:00:37  44.8135  123.1500      2.48
# 3      Castro      BR  2023-01-03 00:00:39 -24.7911  -50.0119     65.10
# 4    Khatanga      RU  2023-01-03 00:00:39  71.9667  102.5000     -7.98
# 5     Ushuaia      AR  2023-01-02 23:59:33 -54.8000  -68.3000     44.26
# 6    Yantzaza      EC  2023-01-03 00:00:40  -3.8278  -78.7594     69.40
# 7  Muravlenko      RU  2023-01-03 00:00:41  63.7898   74.5230      2.97
# 8     Vilhena      BR  2023-01-03 00:00:42 -12.7406  -60.1458     70.02
# 9     Mataura      NZ  2023-01-02 23:59:17 -46.1927  168.8643     76.24
#
#    Humidity  Cloudiness  Wind Speed Current Description
# 0        74          79        9.66          light rain
# 1        77         100       18.97          light rain
# 2        70           0        4.29           clear sky
# 3        93         100        2.46     overcast clouds
# 4        97         100       11.56          light snow
# 5        70          75       32.21       broken clouds
# 6        77          80        1.97       broken clouds
# 7        96         100       16.75          light snow
# 8        97          67        4.03       broken clouds
# 9        43         100        1.23     overcast clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Country', 'Date', 'Lat', 'Lng', 'Max Temp', 'Humidity',
#        'Cloudiness', 'Wind Speed', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order=["City","Country","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df=city_data_df[new_column_order]

# Display sample data
city_data_df.head(10)
# Out:
#          City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Buala      SB  -8.1450  159.5921     84.65        74          79
# 1   Alyangula      AU -13.8483  136.4192     82.74        77         100
# 2     Kaitong      CN  44.8135  123.1500      2.48        70           0
# 3      Castro      BR -24.7911  -50.0119     65.10        93         100
# 4    Khatanga      RU  71.9667  102.5000     -7.98        97         100
# 5     Ushuaia      AR -54.8000  -68.3000     44.26        70          75
# 6    Yantzaza      EC  -3.8278  -78.7594     69.40        77          80
# 7  Muravlenko      RU  63.7898   74.5230      2.97        96         100
# 8     Vilhena      BR -12.7406  -60.1458     70.02        97          67
# 9     Mataura      NZ -46.1927  168.8643     76.24        43         100
#
#    Wind Speed Current Description
# 0        9.66          light rain
# 1       18.97          light rain
# 2        4.29           clear sky
# 3        2.46     overcast clouds
# 4       11.56          light snow
# 5       32.21       broken clouds
# 6        1.97       broken clouds
# 7       16.75          light snow
# 8        4.03       broken clouds
# 9        1.23     overcast clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
